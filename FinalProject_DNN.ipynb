# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/DNN-Rouhani/Final project
# Out:
# /content/drive/MyDrive/DNN-Rouhani/Final project

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/DNN-Rouhani/Final project/.git/

# %%
# !git config --global user.name ""
# !git config --global user.email "ghavams2001@gmail.com"

# %%
# !git remote add origin https://github.com/Sara-Ghavampour/NestedGNN.git

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 461, done.
# remote: Total 461 (delta 0), reused 0 (delta 0), pack-reused 461
# Receiving objects: 100% (461/461), 176.27 KiB | 6.08 MiB/s, done.
# Resolving deltas: 100% (303/303), done.
# From https://github.com/Sara-Ghavampour/NestedGNN
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master

# %%
# !rm -r NestedGNN

# %%
# !git add .
# !git commit -m "hi"
# !git push origin master
# Out:
# [master 966ebe4] hi
#  3 files changed, 3 insertions(+)
#  create mode 100644 FinalProject_DNN.ipynb
#  mode change 100755 => 100644 run_all_targets_qm9.sh
# fatal: could not read Username for 'https://github.com': No such device or address
