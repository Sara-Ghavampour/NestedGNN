# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/DNN-Rouhani/Final project
# Out:
# /content/drive/MyDrive/DNN-Rouhani/Final project

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/DNN-Rouhani/Final project/.git/

# %%
# !git config --global user.name "Sara Ghavampour"
# !git config --global user.email "ghavams2001@gmail.com"

# %%
# !git config --global --unset user.name
# !git config --global --unset user.email

# %%
# !git remote add origin https://github.com/Sara-Ghavampour/NestedGNN.git
# Out:
# fatal: remote origin already exists.

# %%
# !git pull origin master
# Out:
# From https://github.com/Sara-Ghavampour/NestedGNN
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !rm -r NestedGNN

# %%
# !git add .
# !git commit -m "hi"
# !git push origin master
# Out:
# [master 14a324e] hi
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite FinalProject_DNN.ipynb (83%)
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# !git config --global --edit
